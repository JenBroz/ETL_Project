# %%
import pandas as pd

# %%
sales = pd.read_csv('../Data/Sales97.csv')
geo = pd.read_csv('../Data/LatLong_Sales97.csv')

heat_info = geo.join(sales.set_index('Name'), on='Name')

# %%
heat_info.head()
# Out:
#                                                 Name        lat       long  \
# 0  The Castlewood Plan, Meadowlark, Parker, CO 80134  39.584733  39.584733
# 1  Sheridan Plan, Ridgeline At Meridian Village, ...  39.517558  39.517558
# 2                5008 Raintree Cir, Parker, CO 80134  39.448100  39.448100
# 3          10023 S Granite Hill Dr, Parker, CO 80134  39.534697  39.534697
# 4  Lapis Plan, Seasons At Stonegate, Parker, CO 8...  39.548336  39.548336
#
#    Unnamed: 3  Unnamed: 4      House status        Price  \
# 0         NaN         NaN  New construction    $481,990
# 1         NaN         NaN  New construction    $587,950
# 2         NaN         NaN    House for sale  $1,700,000
# 3         NaN         NaN    House for sale    $635,000
# 4         NaN         NaN  New construction    $524,950
#
#                                  Street Address Locality Region  PostalCode  \
# 0               The Castlewood Plan, Meadowlark   Parker     CO       80134
# ...
